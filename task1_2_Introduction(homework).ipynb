# %%
a = 2**179
print(a)
# Out:
# 766247770432944429179173513575154591809369561091801088

# %%
st = 'Python'
print(st * 100)
# Out:
# ...

# %%
from math import sqrt
a = int(input('Введите 1 катет'))
b = int(input('Введите 2 катет'))
c = sqrt((a**2) + b**2)
print('Гипотенуза = ', c)
# Out:
# Введите 1 катет3
# Введите 2 катет4
# Гипотенуза =  5.0

# %%
n = int(input('Количество школьников'))
k = int(input('Количество яблок'))
kol = k//n
print(kol)
# Out:
# Количество школьников3
# Количество яблок14
# 4

# %%
tri = int(input('Введите трехзначное число'))
summa = 0
while tri > 0:
    a = tri % 10
    summa += a
    tri = tri//10
print(summa)
# Out:
# Введите трехзначное число179
# 17
